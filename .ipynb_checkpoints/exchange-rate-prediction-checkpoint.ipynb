# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
df = pd.read_csv("USD_INR_weekly.csv")

# %%
df.head()
# Out:
#            Date   Price    Open    High     Low Change %
# 0  Nov 10, 2019  71.756  71.370  71.758  71.305    0.55%
# 1  Nov 03, 2019  71.360  70.560  71.364  70.560    0.85%
# 2  Oct 27, 2019  70.760  70.819  71.065  70.681   -0.08%
# 3  Oct 20, 2019  70.820  71.080  71.090  70.720   -0.38%
# 4  Oct 13, 2019  71.090  70.893  71.730  70.740    0.23%

# %%
df.tail()
# Out:
#              Date   Price    Open    High     Low Change %
# 730  Nov 13, 2005  45.725  45.685  45.850  45.515    0.37%
# 731  Nov 06, 2005  45.555  45.505  46.045  45.365    0.19%
# 732  Oct 30, 2005  45.470  45.000  45.567  44.980    0.94%
# 733  Oct 23, 2005  45.045  45.035  45.255  44.935    0.01%
# 734  Oct 16, 2005  45.040  44.740  45.435  44.730    0.55%

# %%
plt.figure(figsize=(16,8))
plt.plot(df["Open"])
plt.plot(df["High"])
plt.plot(df["Low"])
plt.plot(df["Price"])
plt.title('USD/INR Weekly exchange rate history')
plt.ylabel('Price (INR)')
plt.xlabel('Days')
plt.legend(['Open','High','Low','Close'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.plot(df_bse["Volume"])
plt.title('BSE SENSEX stock volume history')
plt.ylabel('Volume')
plt.xlabel('Days')
plt.show()

# %%
print("checking if any null values are present\n", df_bse.isna().sum())
# Out:
# checking if any null values are present
#  Date         0
# Open         6
# High         6
# Low          6
# Close        6
# Adj Close    6
# Volume       6
# dtype: int64

# %%
df_bse[df_bse.isna().any(axis=1)]
# Out:
#             Date  Open  High  Low  Close  Adj Close  Volume
# 36    2014-12-26   NaN   NaN  NaN    NaN        NaN     NaN
# 37    2014-12-29   NaN   NaN  NaN    NaN        NaN     NaN
# 40    2015-01-01   NaN   NaN  NaN    NaN        NaN     NaN
# 80    2015-02-28   NaN   NaN  NaN    NaN        NaN     NaN
# 287   2016-01-01   NaN   NaN  NaN    NaN        NaN     NaN
# 1027  2019-01-01   NaN   NaN  NaN    NaN        NaN     NaN

# %%
df_bse = df_bse.interpolate(method='linear', limit_direction='forward')

# %%
#for normalizing data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
#setting index as date
df_bse['Date'] = pd.to_datetime(df_bse.Date,format='%Y-%m-%d')
df_bse.index = df_bse['Date']

#plot
plt.figure(figsize=(16,8))
plt.title('BSE SENSEX stock price history')
plt.ylabel('Closing Price (INR)')
plt.xlabel('Time')
plt.plot(df_bse['Close'], label='Close Price history')

# %%
#split into 80% test and 20% train data
df_bse_train = df_bse[:982]
df_bse_test = df_bse[982:]

# %%
df_bse_train
# Out:
#                  Date          Open          High           Low         Close  \
# Date
# 2014-11-03 2014-11-03  27943.039063  27969.820313  27785.400391  27860.380859
# 2014-11-05 2014-11-05  27907.189453  28010.390625  27857.650391  27915.880859
# 2014-11-07 2014-11-07  27902.710938  27980.929688  27739.560547  27868.630859
# 2014-11-10 2014-11-10  27919.449219  28027.960938  27764.750000  27874.730469
# 2014-11-11 2014-11-11  27911.250000  27996.919922  27790.400391  27910.060547
# ...               ...           ...           ...           ...           ...
# 2018-10-17 2018-10-17  35543.378906  35605.429688  34727.160156  34779.578125
# 2018-10-19 2018-10-19  34563.289063  34563.289063  34140.320313  34315.628906
# 2018-10-22 2018-10-22  34689.390625  34748.691406  34082.761719  34134.378906
# 2018-10-23 2018-10-23  33935.878906  34073.921875  33742.750000  33847.230469
# 2018-10-24 2018-10-24  34203.699219  34300.968750  33726.070313  34033.960938
#
#                Adj Close   Volume
# Date
# 2014-11-03  27860.380859   9500.0
# 2014-11-05  27915.880859   8700.0
# 2014-11-07  27868.630859  10500.0
# 2014-11-10  27874.730469   7900.0
# 2014-11-11  27910.060547   7000.0
# ...                  ...      ...
# 2018-10-17  34779.578125  17700.0
# 2018-10-19  34315.628906  16000.0
# 2018-10-22  34134.378906  17100.0
# 2018-10-23  33847.230469  12700.0
# 2018-10-24  34033.960938  18900.0
#
# [982 rows x 7 columns]

# %%
df_bse_test
# Out:
#                  Date          Open          High           Low         Close  \
# Date
# 2018-10-25 2018-10-25  33778.601563  33838.761719  33553.179688  33690.089844
# 2018-10-26 2018-10-26  33776.800781  33776.800781  33291.578125  33349.308594
# 2018-10-29 2018-10-29  33549.878906  34154.601563  33341.800781  34067.398438
# 2018-10-30 2018-10-30  34068.921875  34176.359375  33799.789063  33891.128906
# 2018-10-31 2018-10-31  33963.089844  34463.378906  33587.238281  34442.050781
# ...               ...           ...           ...           ...           ...
# 2019-10-25 2019-10-25  39201.671875  39241.609375  38718.269531  39058.058594
# 2019-10-29 2019-10-29  39293.488281  39917.011719  39254.121094  39831.839844
# 2019-10-30 2019-10-30  40055.628906  40178.121094  39805.109375  40051.871094
# 2019-10-31 2019-10-31  40211.988281  40392.218750  40054.890625  40129.050781
# 2019-11-01 2019-11-01  40196.070313  40283.300781  40014.230469  40165.031250
#
#                Adj Close     Volume
# Date
# 2018-10-25  33690.089844    17400.0
# 2018-10-26  33349.308594    21300.0
# 2018-10-29  34067.398438    28000.0
# 2018-10-30  33891.128906    15800.0
# 2018-10-31  34442.050781    25900.0
# ...                  ...        ...
# 2019-10-25  39058.058594    48600.0
# 2019-10-29  39831.839844    50500.0
# 2019-10-30  40051.871094    37200.0
# 2019-10-31  40129.050781  8790000.0
# 2019-11-01  40165.031250    57000.0
#
# [247 rows x 7 columns]

# %%
preds = []
for i in range(0, df_bse_test.shape[0]):
    a = df_bse_train['Close'][i:].sum() + sum(preds)
    b = a/len(df_bse_train)
    preds.append(b)

# checking the results (RMSE value)
rms=np.sqrt(np.mean(np.power((np.array(df_bse_test['Close'])-preds),2)))
print('RMSE value on validation set:')
print(rms)
# Out:
# RMSE value on validation set:
# 7661.131225886843

# %%
#plot
plt.figure(figsize=(16,8))
plt.title('BSE SENSEX stock price predictions using moving average')
plt.ylabel('Closing Price (INR)')
plt.xlabel('Time')
df_bse_test = df_bse_test.assign(Predictions = 0)
df_bse_test = df_bse_test.assign(Predictions = preds)
plt.plot(df_bse_train['Close'])
plt.plot(df_bse_test[['Close', 'Predictions']])
# Out:
# [<matplotlib.lines.Line2D at 0x7ff791c4a550>,
#  <matplotlib.lines.Line2D at 0x7ff791c4afd0>]

# %%
from pmdarima.arima import auto_arima

training = df_bse_train['Close']
validation = df_bse_test['Close']

model = auto_arima(training, start_p=1, start_q=1, max_p=1, max_q=1, m=12, start_P=0, seasonal=True, d=1, D=1, trace=True, error_action='ignore', suppress_warnings=True)
model.fit(training)

forecast = model.predict(n_periods=len(validation))
forecast = pd.DataFrame(forecast,index = df_bse_test.index,columns=['Prediction'])
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=13481.263, BIC=13505.644, Fit time=8.690 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=14035.140, BIC=14044.893, Fit time=0.066 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=13790.009, BIC=13809.514, Fit time=2.562 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=13480.018, BIC=13499.523, Fit time=3.366 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=13478.876, BIC=13503.257, Fit time=4.511 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 0, 12); AIC=13789.659, BIC=13809.164, Fit time=2.406 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=13483.526, BIC=13512.784, Fit time=32.426 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=14027.266, BIC=14041.895, Fit time=0.279 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=13478.381, BIC=13512.515, Fit time=36.602 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=13483.165, BIC=13522.176, Fit time=41.285 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(2, 1, 2, 12); AIC=13483.471, BIC=13512.729, Fit time=30.440 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 1, 1, 12); AIC=13482.363, BIC=13511.620, Fit time=23.022 seconds
# Total fit time: 185.659 seconds

# %%
#rms
rms=np.sqrt(np.mean(np.power((np.array(df_bse_test['Close'])-np.array(forecast['Prediction'])),2)))
rms
# Out:
# 2443.569878053116

# %%
#plot
plt.figure(figsize=(16,8))
plt.title('BSE SENSEX stock price predictions using ARIMA')
plt.ylabel('Closing Price (INR)')
plt.xlabel('Time')
plt.plot(df_bse_train['Close'])
plt.plot(df_bse_test['Close'])
plt.plot(forecast['Prediction'])
